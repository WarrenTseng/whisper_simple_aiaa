# %%
# Install requirements
# !pip install --upgrade pip
# !pip install --upgrade git+https://github.com/huggingface/transformers.git accelerate datasets[audio]

# %% [markdown]
# ## Simple usage

# %%
from whisper_aiaa import WhisperAIAA

wa = WhisperAIAA()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
audio_path = 'dataset/zh_sample1.wav'

# %%
wa.inference(audio_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:480: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# ...

# %%
import IPython.display
IPython.display.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wa.annotate('大家好,我是Warren,請多多指教。', audio_path)

# %% [markdown]
# ## With "next" function - data collected in the "dataset" folder

# %%
from whisper_aiaa import WhisperAIAA

wa = WhisperAIAA(audio_folder='dataset')
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
audio_path, text = wa._next()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:480: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# ...

# %%
audio_path, text
# Out:
# ('dataset/zh_sample1.wav', '大家好,我是Warren,請多多指教')

# %%
import IPython.display
IPython.display.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wa.annotate('大家好,我是Warren,請多多指教。', audio_path)

# %%
audio_path, text = wa._next()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:480: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(

# %%
audio_path, text
# Out:
# ('dataset/zh_sample2.wav', '大家好,我是Warren,請多多指教')

# %% [markdown]
# ## With simple Flask app - data collected in the "dataset" folder

# %% [markdown]
# Run the command below in your terminal in this folder:
# ```
# $flask run
# ```
# Then open your browser
